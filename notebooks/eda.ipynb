# %% [markdown]
# # Φάση Β: Exploratory Data Analysis
#
# **Υπεύθυνος:** Data Analyst
#
# **Βήματα:**
# 1. Στατιστική ανάλυση
# 2. Κατανομές μεταβλητών
# 3. Correlation analysis
# 4. Visualizations (histograms, box plots, heatmaps)
# 5. Insights & συμπεράσματα
